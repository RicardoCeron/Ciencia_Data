# %%
5+5
# Out:
# 10

# %%
print("Helo, World!")
# Out:
# Helo, World

# %%
variable_Carro =10
variable_carro2=20
print(variable_Carro + variable_carro2)
# Out:
# 30

# %%
caballo = 10
liebre = 5
if caballo > liebre:
    print("El caballo es más rápido que la liebre")
# Out:
# El caballo es más rápido que la liebre
